# %%
import csv

# %%
f = open('data.csv', 'rb')
reader = csv.reader(f)
cig = []
leuk = []
for row in reader:
    a = row [0]
    b = a.replace ("\t" ," ")
    c = b.split()
    cig.append(c[1])
    leuk.append(c[5])
cig = map(float,cig)
leuk = map(float,leuk)
print cig
print leuk
f.close()
# Out:
# [18.2, 25.82, 18.24, 28.6, 31.1, 33.6, 40.46, 28.27, 20.1, 27.91, 26.18, 22.12, 21.84, 23.44, 21.58, 28.92, 25.91, 26.92, 24.96, 22.06, 16.08, 27.56, 23.75, 23.32, 42.4, 28.64, 21.16, 29.14, 19.96, 26.38, 23.44, 23.78, 29.18, 18.06, 20.94, 20.08, 22.57, 14.0, 25.89, 21.17, 21.25, 22.86, 28.04, 30.34]
# [6.15, 6.61, 6.94, 7.06, 7.2, 6.45, 7.08, 6.07, 6.62, 7.27, 7.0, 7.69, 7.42, 6.41, 6.71, 6.24, 6.81, 6.89, 6.91, 8.28, 6.08, 6.82, 6.9, 7.8, 6.67, 7.12, 5.95, 7.23, 6.99, 7.38, 7.46, 6.83, 6.35, 5.82, 8.15, 6.59, 7.02, 6.71, 6.56, 7.48, 6.73, 7.38, 5.78, 4.9]

# %%
from pylab import *

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_title('No. of cigarettes & leukemia victims')
ax.set_ylabel('No. of leukemia victims per 100K person')
ax.set_xlabel('No. of cigarettes')
ax.scatter(cig, leuk)

# %% [markdown]
# This scatter plot shows the number of cigarettes that are smoked in 44 states and the percentage of people that die because of leukemia which is caused because of cigarettes in the same state.

# %%
f = open('data.csv', 'rb')
reader = csv.reader(f)
blad = []
lung = []
for row in reader:
    a = row [0]
    b = a.replace ("\t" ," ")
    c = b.split()
    blad.append(c[2])
    lung.append(c[3])
blad = map(float,blad)
lung = map(float,lung)
print blad
print lung
f.close()
# Out:
# [2.9, 3.52, 2.99, 4.46, 5.11, 4.78, 5.6, 4.46, 3.08, 4.75, 4.09, 4.23, 2.91, 2.86, 4.65, 4.79, 5.21, 4.69, 5.27, 3.72, 3.06, 4.04, 3.95, 3.72, 6.54, 5.98, 2.9, 5.3, 2.89, 4.47, 2.93, 4.89, 4.99, 3.25, 3.64, 2.94, 3.21, 3.31, 4.63, 4.04, 5.14, 4.78, 3.2, 3.46]
# [17.05, 19.8, 15.98, 22.07, 22.83, 24.55, 27.27, 23.57, 13.58, 22.8, 20.3, 16.59, 16.84, 17.71, 25.45, 20.94, 26.48, 22.04, 22.72, 14.2, 15.6, 20.98, 19.5, 16.7, 23.03, 25.95, 14.59, 25.02, 12.12, 21.89, 19.45, 12.11, 23.68, 17.45, 14.11, 17.6, 20.74, 12.01, 21.22, 20.34, 20.55, 15.53, 15.92, 25.88]

# %%
from pylab import *

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_title('Percentage of bladder cancer & lung cancer victims')
ax.set_xlabel('Bladder cancer victims')
ax.set_ylabel('Lung cancer victims')
ax.scatter(blad, lung)

# %% [markdown]
# This plot shows both the percantage of people dying because bladder cancer and people dying because of lung cancer in 44 different states. These deathe
