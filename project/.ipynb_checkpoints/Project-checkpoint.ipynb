# %%
import csv

# %%
f = open('data.csv', 'rb')
reader = csv.reader(f)
cig = []
leuk = []
for row in reader:
    a = row [0]
    b = a.replace ("\t" ," ")
    c = b.split()
    cig.append(c[1])
    leuk.append(c[5])
cig = map(float,c)
leuk = map(float,c)
print cig
print leuk
f.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-0bdb40d8de48> in <module>()
#       7     b = a.replace ("\t" ," ")
#       8     c = b.split()
# ----> 9     cig = map(float,c)
#      10     leuk = map(float,c)
#      11     cig.append(c[1])
#
# ValueError: could not convert string to float: AL

# %%
from pylab import *

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_title('No. of cigarettes & leukemia victims')
ax.set_xlabel('No. of leukimia victims')
ax.set_ylabel('No. of cigarettes')
ax.scatter(cig, leuk)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-0c7113f5f7fe> in <module>()
#       4 ax.set_xlabel('No. of leukimia victims')
#       5 ax.set_ylabel('No. of cigarettes')
# ----> 6 ax.scatter(cig, leuk)
#
# /usr/lib/pymodules/python2.7/matplotlib/axes.pyc in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, faceted, verts, **kwargs)
#    5874             self.set_ymargin(0.05)
#    5875
# -> 5876         self.add_collection(collection)
#    5877         self.autoscale_view()
#    5878
#
# /usr/lib/pymodules/python2.7/matplotlib/axes.pyc in add_collection(self, collection, autolim)
#    1443         if autolim:
#    1444             if collection._paths and len(collection._paths):
# -> 1445                 self.update_datalim(collection.get_datalim(self.transData))
#    1446
# ...
